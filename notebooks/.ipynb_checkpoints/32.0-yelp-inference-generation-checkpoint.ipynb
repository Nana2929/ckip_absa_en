# %% [markdown]
# ## Yelp inference (test-set) generation

# %%
YELPPATH = '/share/data/yelp'
RP = 'yelp_academic_dataset_review.json'
BUSINESS = 'yelp_academic_dataset_business.json'
rppath = f'{YELPPATH}/{RP}'
busipath = f'{YELPPATH}/{BUSINESS}'

# %%
import pandas as pd
import json

# %%
Bid2Info = {}
with open (busipath, 'r') as f:
    for line in f:
        line = json.loads(line)
        busi_id = line['business_id']
        category = line['categories']
        
        name = line['name']
        star = line['stars']
        Bid2Info[busi_id] = {'name':name, 
                             'category':category, 
                             'star':star, 
                             'review_ids':[], 
                             'business_id':busi_id}

# %%
tags = set()
from collections import defaultdict
counter = defaultdict(int)
NoCat = 0 
for ts in Bid2Info.values():
    try:
        ts = ts['category'].split(',')
    except:
        NoCat += 1
        continue
    for t in ts:
        t = t.strip()
        tags.add(t)
        counter[t]+=1
print(f'No category: {NoCat}')
# print(f'#tags: {len(tags)}')
# Out:
# No category: 103

# %%
path = '../data/yelp_tags.csv'
tags = pd.DataFrame({'tag': list(tags)})
tags.to_csv(path, index = False)

# %%
scounter = sorted(counter.items(), key = lambda x:-x[1])
# ('Eyewear & Opticians', 1016)
scounter.index(('Eyewear & Opticians', 1016)) # 124
# scounter[:124]
# Out:
# 124

# %%
import sys
# caution: path[0] is reserved for script path (or '' in REPL)
sys.path.insert(1, '../data')
from yelp_tags import YelpFoodTags

RID_Dict = {}
FoodReviewIDs = set()
isCoveredReview = 0 
YelpFoodTags = set(YelpFoodTags)
KnownRestaurants = set()
with open (rppath, 'r') as f:
    for id, line in enumerate(f):
        line = json.loads(line)
        store = Bid2Info[line['business_id']]
        # 'Shipping Centers, Local Services, Notaries, Mailbox Centers, Printing Services'
        flag = False
        if store['business_id'] in KnownRestaurants:
            isCoveredReview += 1 
            flag = True
        elif store['category']:
            for tag in store['category'].split(','):
                tag = tag.strip()
                if tag in YelpFoodTags:
                    isCoveredReview += 1
                    flag = True
                    KnownRestaurants.add(store['business_id'])
                break 
        if flag:
            FoodReviewIDs.add(line['review_id'])
            
        RID_Dict[line['review_id']] = line

# %%
MYSEED = 1024
import random 
random.seed(MYSEED)
print(f'Successfully seeding {MYSEED}')
len(FoodReviewIDs)
# Out:
# Successfully seeding 1024
# 44555

# %% [markdown]
# ### Generate random/general inference data
# - 100 筆

# %%
n = 100
chosenIDs = random.sample(FoodReviewIDs, n)
chosenReviews = [RID_Dict[x] for x in chosenIDs]

# %%
import json 
with open('../data/yelp-food-test100.json', 'w') as f:
    json.dump(chosenReviews, f)

# %% [markdown]
# ### Generate restaurant-specific data

# %%
## add review number attribute
for frid in FoodReviewIDs:
    review = RID_Dict[frid]
    bid = review['business_id']
    if bid == '_ab50qdWOk0DdB6XOrBitw':
        print('!')
    Bid2Info[bid]['review_ids'].append(frid)    
sbid = sorted(Bid2Info.items(), key = lambda x:-len(x[1]['review_ids']))

# %%
# randomly pick from these 2 resta
# Out:
# {'Mm6dl2ZANXk4vzzJ9Nztjg',
#  'z4Xtxe6demG-4N5KkkSE1Q',
#  'k9DdPdI1gF8K4tkIuvp02A',
#  'F-DYslH7w4jfxfACNrRKNA',
#  'f57iqQ8dnQLYq3bcrLD7Qg',
#  '1JViNL_VNI8tBjHmtojEQw',
#  '0W2KiL_Rgqd9GvIjFNpGEA',
#  'U2kb6WvFHIdLWuXL5dLKPQ',
#  'KW2RrtrPWyeBeYlyd2vQ4Q',
#  'BK_k_IUsEHMagmHffdD-bA',
#  'q09EustC0HN2KMP5-EkuKg',
#  'ZEzC-_x0hc6bDC0aHymywQ',
#  '95ObZeCtNILkMzAN2IShOg',
#  'dSD4WmBMYqWY5vj8L4Rr_Q',
#  'icRR4qIwgl9Z_zIYf-pi7Q',
#  'q7Ws2ivuReuAXAd3FxJizw',
#  'BCjaPNM_MkQYmr_8wcrDUg',
#  '3xwr6ZAzr0G4lT1iXfoR9w',
#  'NFHXnOKfJBYIXNqpxfTIXg',
#  'OwWs4uIEa7Ku00PjCYJLKw',
#  'yXmlElvKxV6FvAlOCKaVfA',
#  'VIUwZgCQnwpbB2w2Xbr5CA',
#  'HX5NSN8QVPSLKWVP4gtwNQ',
#  'z9EMTyvEC97ctufcFqQrhQ',
#  'GXWLELDC9zBlIve_zr8_yg',
#  'hU9PXpBfS0r7znrM8PiipA',
#  'AlcXocLsvTBNVNtOb7k5gw',
#  'nIBJCJohyaFjcqwrjZkJ3A',
#  'dCKYcIuhOhRR3655x4Eq5Q',
#  'vKKKPhWcyGGp2fR78_7ZLg',
#  'SscWp3LWat9g-OeMJ90idw',
#  '1Qsgm63Bff1l3s7CWtWQCw',
#  '_h6g05qFAtg5uvneDmHVpw',
#  '6Kja66E10JI2zjl-G7zMSg',
#  'Bus_xuP6j5BrRpam_mZsuQ',
#  '87G2E8eqekaqs1YCJgBhfg',
#  'zGir0CMCi2jL-_0BFQnIpg',
#  'YgQWa7gbZ9NHKahaDQoSZA',
#  'RESQo_Z34a0zx2NgrsiwXw',
#  'Gyw77tgrqdHnDBI6WfFjMw',
#  'MVZVJhYDpOJ9g5RLmVB11A',
#  'vJYrthDMB2RRZ-Nk20dDag',
#  'axmk7p8xYTxWoYZ8VRK3rw',
#  'pN_ib3YPhIEDaCrG6ZC21Q',
#  'ilq3ETZqjIZFZahG4gi3Eg',
#  '9sEwPyteyu3cmxbtLZkYEw',
#  'PSyOcpnYhbof1xg7V2XLpA',
#  'NWEG1YEgxt9-wMWzq4Bmaw',
#  'hE1twczcbuRfoTAKfiM9Ew',
#  '5ZJLAzN2hmWlGTtRkO2NPQ',
#  'gOwb3XmZUICMdaOODtX56w',
#  'y-2vDg48g1OST135wkjrTw',
#  'icblXGnalQQ21GKyK6AymQ',
#  'NguqVp2jHUgf3sBy7TdISw',
#  'ombXBAPngpO8rKTb2C0isQ',
#  'hKG5f0eVmPziSLikVfgzpw',
#  '818-bP2UnO1-gd8iacRJiw',
#  'vhKRkZgkvBplorNhNYp2dA',
#  'orONaQ2AhdG9Hk_p8OG4GQ',
#  'PInjyonrFnEW_IaTGSLqXg',
#  'Iwbhy3f2mW3Z-EuDyiDtHA',
#  '82QbCXjn4j_iJCP2Rxl-UQ',
#  'w50YhqMSC-sB3z2RR098CA',
#  'ALo1PmhGFwugESp4mGjcMQ',
#  '8v8aJt3rczMIz04klZLvtg',
#  'yx4UQWHUdyDSYJ5VScKVDg',
#  'tFkCI0kR0b-mdNLiXlrLlQ',
#  'W84J8-PjLzmPpLHHoWnz-A',
#  '-frAeXUK8gcD6Lmh6zIXRg',
#  'Rx2Ci_LkXDLdSdetNEmUEA',
#  '0xGNmy8DERwwqO3V5jNR6Q',
#  'Wiv0PglxsM5VB9HH71WR8Q',
#  'YBV5Kc0kKGfp214vwr6oYQ',
#  'J6PKF46lGn40cWFdDvPemw',
#  '_uciUaZjaShfJ_gppbg-7w',
#  'dbejEZb7EsfgvwXm0j5QYQ',
#  'yLI1y3cXoncv_twYRgM6iA',
#  'S_y6q20hJGag3gyRAWM4zw',
#  'F1kZtf0VdlOYhf_pkoA9vg',
#  'MbfMd1PSYmi21DeKTISsOw',
#  'b9Co3jXNV4AcxzS8iN4M3Q',
#  'TfM90hDsJ-2L80zfp4XKIg',
#  'fQC9ZyOScQATBftJUWZS0A',
#  'GLufJ7KeZ_2XWifhPihr1Q',
#  'jv0w9yB3dOVg2vYOXt_ggg',
#  'Me3ectPO7O6PHKi1xengMA',
#  'i5onMfJXVjQONr-5nCINlA',
#  'pCmxYuTBOmGNwYQxvgswBg',
#  '39vQwcxbLGuA8s0n6emUMQ',
#  'yy8x-eANwJbwU-bFF2r8Hg',
#  'SepRFQcynFIuZzDbAxgHUw',
#  'qXh01AUTRI0wk3YhUX90nw',
#  'PZ51H-WM0YuY74W-OUId5w',
#  '1bk1byIFSJcbd2_uptpv1A',
#  'MALJjpMdhYLrI4eY5J-FOA',
#  '7-xDE6_8Ii-kMKu32TZYFA',
#  'BVTZezyh4ovkkHvZqVqDTw',
#  'OD-avsNVUPkFC9aHmYxa1Q',
#  'GQS6-DPo_IG0mynkxpFuog',
#  '2a_1USZZv9iBu2xC_bIY_Q',
#  'v-o7tkWEXBbtHaTTQAgwQA',
#  '3YbVt_AR6ZJbK_5tkcIx_w',
#  'WmlolCfbYorsxtErbvXlKQ',
#  'rxt6O6uEftjn9hAADToD6A',
#  'A3WFjgcGqgllnM9l5uBTkw',
#  'ZqPXwnHfkyiizL4qr16ViQ',
#  'HO5xITRVj3a-tqp14K5UoA',
#  'jHgKrtZ1faGzfyWz0WVEmQ',
#  'RBgZbyTl44wdfwCK6SlFjw',
#  'qjCugQiu-jUXz3vihPpYEA',
#  '1RkS6L0Bff8uEBQSLLITig',
#  'O7CqdKyw5YDT7GYE_AJSng',
#  'nBGvD9lFMyZ_UkjGRQOTAg',
#  'L2xTJ8WOGl6zeKXpk9YsUQ',
#  'j7hM6LJ6BClHVAjQeChmSw',
#  'Woakos5xpc9X-ai0xyyK6g',
#  'qZdrLDkxgy-QVIm7WAzBSA',
#  'ZowAa0BTHsuBUjUlYSfLWQ',
#  'BMShqa7tjaiqzcNGF8tCPw',
#  'MQc8Bp8gRPCHoTgSs93FBw',
#  '9o3d7mFzss7_vutddiM0rg',
#  'LJdZMbmxwyjEi4SzP2__RQ',
#  '-P79irf_wstPiL7Gtlbv8A',
#  'gg4Xz8Z2eL4PTVOHBqGzOw',
#  'uhONoITR_jaNFgteC74BFg',
#  'pRYz-K3eUUCHdVIxzHTcsw',
#  'UYXZJ3TucodCoPyhNOhIeA',
#  'KqbboNdh6ksKqWk6OkODdA',
#  'qctyziKhqa_BY8KD3keT5A',
#  'Y7qvkiTotKgigWASCoMFsg',
#  'm5vdDm6BIGGtI7QpOLMJwQ',
#  'rYFBv1rULwiA74Fh992n_w',
#  'jEPv_-azPJPp_hy4t1L_AA',
#  'ftFSvSLivc2rkeBKH1cmPQ',
#  'S4HvYwZavIG95g62lwYyfg',
#  'PL4RriXs8N6RxDUS8IF-Ww',
#  'sFnGzOZJR0xX0Ud1d-SO7Q',
#  'ZKNtyjTBqsvH2MmVQX1vQQ',
#  'L7I4_9xAgjnuG18ErvzXqg',
#  'q5mjIR-FWV1skRlaWRa5qw',
#  'xsjoOjVJexba5uRXlLjwEg',
#  'kijvdb7sPITtgyf3nMn4ZA',
#  'm1VwfXnulNWxVW2DMQRZ0Q',
#  'uEkMkU7QdEmYVuKAFbepIw',
#  '77Ums_kOIKde4g6U8p2dLg',
#  'f3zbRHli2j1mBaShGA-6Tw',
#  'M0yQYvGzM0hzc27CFhb4FQ',
#  'WHscUA0gQbaq_AzzbNYDkg',
#  'RdReMwfvDV9JzSgQhNEAew',
#  '2Xbm5hNOFVNoJVw9MxBnRA',
#  'YQUaU7NCbeI4LOZMXto9OA',
#  'L9I-1ueKXj8hf8IiHYfMGg',
#  'DB6UIIwCkW2HHkm1-EZyIg',
#  'V17qwKcZmj6CUtQVRbH3CQ',
#  'Mu94N4vOiPMbtD1KznLkWA',
#  'p_uBIKyH8cZI6Cyhq7l2BA',
#  'Y5vkEvihVE9f3dHHDgeJaQ',
#  'SDqfvZ5t2Qja-JuFBY6MMw',
#  'DyO3oHJPqRwuxEZbcrljYg',
#  'pgkCjyokmlzFXU9s4u7FjQ',
#  'OJRsO9zzicX7glHiE0IdlA',
#  'OI6hq_7xWuK4JuFpkw_nqw',
#  '3skU1zksJyB0CExNkWu4PA',
#  'N-PulW9vplLBr46HSIU8Jw',
#  'vPMiq7_s7MRPqtnzfH6W_Q',
#  'w4N9zTKdgp5o7af3Ji7RsQ',
#  'XfkTITcAYp44nHm5jfoUTQ',
#  'XpOt3x4oWv4BuGXBeYOZdQ',
#  'dCSaRxqIUEVo9a9ZLRdUgg',
#  '5o9_YJ9wP-ZSAyRbZO8F0g',
#  'wdja_4xEsUzKSY1vve9kRw',
#  'Csvaq-O0t-aG2psKpObI0g',
#  'LF5hamyVQyRDqTIWJliKeQ',
#  'e5Cwu5wG078NgojHlo0lEA',
#  'VZsWYW3SgVyop1q4DroEEA',
#  'W61O5uq_Oxs8l0F2gJNDUQ',
#  'WInlMIojzki5CSxGviodog',
#  'xJB3vu-f54iUETYShsLNuQ',
#  '9rTTG75sS0VxOWTgG5Eh9A',
#  'SC1D4FnOxfNH4l2Tgog7Ug',
#  'sOFygceUO5YMIyITXLANPA',
#  '2JBCOwTQdhETdRhZ1-eF6A',
#  'ztej3wN6GpL_nflhTPUCxw',
#  'QzrDH8TQeJAOE1nwNd5YQA',
#  'XDuFTSKDR4Lf6EYDinM60w',
#  'fRAtN9IZ8cKrHWe7CNcK8w',
#  'ARZeFxIyyX0xl2Lvc-lSsg',
#  '71gjWp-eZutaWr4EqjOmDg',
#  'FOdwHF4T0sCa5FvsTEc6DA',
#  '__kJephIqp7E58IJ7aIdtQ',
#  '6YzSJZb5Yb9Dx8GtqAPpAg',
#  'YJicaq1YnLWuc-rgtrPiKw',
#  'Yo8kMawqqpxzJFKgXcesCw',
#  'qzZPA2QT7QVGXb4YFKEwAA',
#  'WVjaXPyAyMuHTtpBIE8ZUQ',
#  'O-Z5_d9IFXhMdDuG84Y9Sw',
#  'cgNCCJvZAyST9g4Bw1fGiA',
#  '7sgPj9QQI1YAhaigw-bI0Q',
#  'ldmlra49pXTXBOzwcEDk7g',
#  '4uEQ0gMjxkAJn_UxoSxmwA',
#  'r1TstoVw4pthjgcIU-UTRg',
#  'Y3CHjbNamfvYlJlCncJiVg',
#  'YBICKu3nIrpNaheF9cxHsg',
#  'PEpf0tv0j8YsZVYoaPs9Sg',
#  'Wa9JlI-cCTgYx2iLV8lpcA',
#  'ltc_wTt_0pV5TvsRyepy9w',
#  'FLzPifV3ODOLNzuihYXcoQ',
#  'OVA9beFUiBEUFe-XlVOpZQ',
#  'veDbScGAkSVrSh9HdtByUw',
#  'AD7duKDC-JSPJtN8Grk0cg',
#  'OIyXQq6-5sJ8LWTk-0irAQ',
#  'dXYPZqEKXiAcGjwLj_U4wg',
#  'tsJWpnRnsDpXK-ukQmvXZQ',
#  'I7laOmL7jGr1ZB9sGX4WrA',
#  'Y9Joikamds6yxTuX4vuK1Q',
#  'nmbSDD1fvTDnH9VRNIRz-w',
#  '-hz4VI1FUHs_mi6z8qZa6g',
#  'PVsjGdbL3TkfS_VNQhYnDw',
#  '37F5xYd8YKBOr3VQjNlZlg',
#  '-wg8-n-Ocrk-x9k-ZxWJVA',
#  'TIyLrC4yA8Y_O-O42eOiwA',
#  'P9EISfAz-7AHMC6nTE_nSg',
#  'F4XjhAQ6NPUtqlXiJ-cSIA',
#  '6olDtvHy02TKRPaV4Dp95w',
#  'E3pT_tqluGmak2Nxn55MNQ',
#  'RrmKlxcxHNRDF6q6eYDIcw',
#  'UB09B-fPspLxG5okb_Galg',
#  'l9uGL-4UZ9_U6_Cf02JqWQ',
#  'RNwLknUtNSbnUR4_oNnXfA',
#  'Zzft9J-tqOsaui4yQGrylw',
#  'ZyvOKOCSMZc7XGzqzub5LA',
#  '-ejV_bqVzMTQs6Tx45c-Kw',
#  'NuCux_qA_XeQOg42tWBXhA',
#  '_eFDPVNxQMzPmj_M7m6i_g',
#  'bk5jrp75J0N31YeQQycGSw',
#  '5vXqVQewEsPELX_RYS1M5g',
#  'vu80kvJbzsmhD52QqfCTgQ',
#  'M-tWnGvxOaybucV48SRqaQ',
#  'BHcdBk-ZJi5eqFNtBQwLHA',
#  'd_NZZR1YqKMO5qJiKwDL7g',
#  '3Bz5wJsYJ59P6cgJHgyGIA',
#  'cySyph8KEHWDwEkxSb_8FQ',
#  'r3CW4efRB4BzBzXH1hTXPQ',
#  '6G0CF7u8vYUDdyQDZoN99g',
#  '4n4IQspJNuSPZUYjdnEoiw',
#  '_LTTkY5Dx1UDVFkoNgnDbA',
#  'Z6OQca7VJCOPuGWauAWjSg',
#  '-Jl0Tnp5r_yweNi76PmMmA',
#  'a8wvQbAtrYgMJivr9zhzHg',
#  'Zw69aRWKoy9VJkXuVN4FAA',
#  'od_ZnyXXTUxn4W0-Vg68jQ',
#  'pfmUzFLB1QqSwQplrA5oTw',
#  'HEFeHiC2WsHwCRS2KbzF7w',
#  'MO87rAGDCHdG6n2dYM5VTQ',
#  '9CfnljkIGuIpI63xsQEd_g',
#  'geCyK2kakefuukFPWEZ1lA',
#  '8gciuUvF5NQ1wK9iPOC8Dw',
#  'mYudezCHNe4r3hdIDST4hw',
#  'vFb0nNL3-6cgT11lAL2BDQ',
#  'JCqtHg2NtqP5QSjtHsKNcw',
#  '4CfKcIf18lE624ZF8RpERQ',
#  '_ZpPcnQbwVwP6F1kHuRHvA',
#  'QK1nsNOUJihxWAuo_L_nYw',
#  'MTv1-yJv-xOMYln3YrHlQA',
#  'eaoaQ2LaYX_1t8ZjVLiX2Q',
#  'xAY6k0korYAw_1idl-0J9A',
#  '1K4_FbcdGTKiZz-0pW6WYw',
#  'G_8x7GSTlww4lVBuf2USGA',
#  'ZPyABqL-tiF255o8v-7gpw',
#  'UnlxX6CG7VVlbtcsDz8sJQ',
#  'IGjLplQUfpmejsJNHpPBHw',
#  'jvV14HrUiv1FBKGmVaiTNA',
#  'OxfE5l_HxAsbqTyyPNUD3Q',
#  'eReieASV-nuPHjukM-PFgQ',
#  'WywM9xCxW_mVjdd9fikKqQ',
#  'cv5vpMgDY1zLQI4X3JeSkA',
#  'GVaYH9hpSGjLWXHwuXy3Tw',
#  'RKHaw1qauoiYfhPN1Ht7Zg',
#  'vsIMf2oaQiNql7WtKtY_fQ',
#  'okooUKKmixCY87ExVoQhWQ',
#  'p0I9xz6DI1TijItUSHDmMA',
#  'G2rDmgUjioqwMcP94UkLvQ',
#  'JWTsUa58hs44xy1W-vAEfw',
#  'pn4XKML8GjDfSxEQVHB45g',
#  '_PBIQRCRa0T9N3S3W_1CXA',
#  'xoptzPP77ajvhB9FuO5vhg',
#  'wp2w973xh0TORSNFxMiOdA',
#  'VKMFEpX7rSOCr6RE7ZPreQ',
#  'frJjShBb_9lK-SqCqpDkmA',
#  '1kGdCS6xvWZAKO29_57cOw',
#  'T3sz5rNacAv_YeiFwqsgAA',
#  'D24MWYbf-EiSeU76dWz9ng',
#  'pj6QSlrcNGTxtAexKlC0Dg',
#  'JBy3Zr_XqUOXAvCJietA9A',
#  'JlUm213jgmZ0GEd4DjyHJA',
#  'klfFYagc-vxNMRV9YPFS3A',
#  'vGdGb3x8R0EeW-D5jxQrTw',
#  'HH22PvZRZm86jspDMkalgQ',
#  'HWTPvKiDa3KgwOcLmf225A',
#  'XT8Dt4D1isNRGCddK_2V2g',
#  'gtB7jadz3jSlM1PNDullXA',
#  'uOYRZ6p0bjblnfXnahowkg',
#  'QoPEr3-JPyBVSonk5Wb3JA',
#  'SATQNMjqH-YYqCSAC9fZug',
#  'OtZaAUSZI-IJ0Xz6CaJ8DA',
#  '5O8pWC5j-ZvO8EchTdTylA',
#  'm-lkYKqeYNdPyuwklcRG1g',
#  '1D5bLdbASdev6pZ1aCXnug',
#  'Mond3z2ps7IQGUvsNqi4_Q',
#  'Bh3dd8G_DFYqkYEGMZ0X9A',
#  'eSQATTmmx1j09oMdTjLB5A',
#  'rskNmRsxBNPx4l124rOEpw',
#  'A2L1pKw2SjVCi3sbHtUgNA',
#  'rBfeM4WfYtwwbVEFWT8XRw',
#  'zmIS0uZvLbAgCVe_hA6c_Q',
#  'bKZ2UyY7eRkFuzhTJVJT2w',
#  '4cMPclZR_qNdM_eqPiteuA',
#  'hn0Aln_4DbPpjg17zdV2yQ',
#  '_A9Nhd9tCrIbuUrWrn5Q7Q',
#  'cNAPnmzhPaC5xpnfjVM9mw',
#  'NWwfDPG19mNa9lTesh6OGg',
#  'Nqq16GCLL6_bwaTu6WAJIQ',
#  '2inGvei77L340yhzRlqkfQ',
#  'OhNP2lT8bt5YEPu9r2fnrA',
#  'Atq8f8ptI8LsBNJfvU5XHA',
#  'XSiL0bd1I9fCJ_uoPcEtgw',
#  'JCB6pOcBGOQyRBh1WpILvg',
#  'SlQztEjq9LTMm0R5Hrs94w',
#  'xHZFGtI4kutNgMBlWnn0VA',
#  '1d0nwoxAnP1SNgydKj7s2w',
#  'qJnHqYWP1Pdwc29tybBdWw',
#  '-gzmpjBDOqXpickG5fOlLA',
#  'VtUR6HVxYB9eHGbrYIXmKw',
#  'm4Cc499VzEHeD90q9ksm1A',
#  'aKdOS0PGUx7htxVYZgvZ6A',
#  'tOyQCWY-9gBvuSiF7Web_g',
#  'h8gtw3w6p52zK9zZSw_Eqw',
#  '_LFXCCsH-o8Cgc24_l8rlA',
#  '52eOrsdLNHpHVjDR0IRHzw',
#  '1_Af8tRa8iHCwoo63vNXdQ',
#  '6xmiA31BmECMdTEPUAsbrA',
#  'Dl8GIcz2NxXpXi2k5bbLIw',
#  'CW1rhomLctADbWLBR6rcgA',
#  'UnqeLsVOV2DiHlU61od_1w',
#  'P0RZEOvnNpnlUYpPNhcbcg',
#  '8kbVI2tNRW7pXxG85R-5sQ',
#  'yYx5UUxABq2dijrl4y5_UA',
#  'L6NBDzT50yaRp9kRkj_apQ',
#  'E1uFMyEwyOsPxYLST9jKGQ',
#  '1wvq5qINzi7NApkx-2KqSA',
#  'z1qT-HDaf14qz3yoRkXSGQ',
#  'rYNQXM5IWg-yI4m_ozNPQQ',
#  'Sc6sRRMIrV9CVBrvwCnT7w',
#  'DhalSMGSw-0S64piQVLJUg',
#  'pEDCOaTm63xVGd4woT81bA',
#  'Hx5lOk4EvfC9ZRHLBRow_g',
#  'YErfoYA3cc4jYw_HQLU74A',
#  'fZL6fBv1bTKTpK7ZIXgjSQ',
#  'rRJxFG6uHVd7xYmoB0lRTw',
#  'guLTgsJSUvN9hUb419c5Nw',
#  'fytzbHMYGfRbxNpa-2dzkw',
#  '5GNDjFV7Vi7Uganf6OlAbg',
#  'nkmaROuFV3qx9XJ1d-BtFA',
#  '0lFD7xu0Xf7Kpll3yPwL5Q',
#  'SIy14n8e_r3Dje2OOOzMIw',
#  'wIPzg2A_70FuMGSx6cwfog',
#  'kXDP-WPIKzy30eytwZjXyQ',
#  'mkmZnDRhivZCvOjDedVkCg',
#  'lii1nh7Hm4qOqhvdvJ_vtg',
#  'u5Wx53mpCKwdMe25qaOBSA',
#  'g_DVHw65mv3qJyvplr-ORQ',
#  'gt8KBlLXjj_yhgjQsYJiSQ',
#  '7Xg1HR9uzGdbqRw6xaZMLg',
#  'DFHdhML_27R0Ha6bpGqX2g',
#  '-swHmk3be9E4yjKmes2Ypw',
#  'XnhcPwnTup-hyRzLStK7fQ',
#  'tJFU2MQADHmQ5tgNZ93otg',
#  'FdIwiDFVsqe1agluOIPD3w',
#  'gfr1aDkeYlYnPbJcjDkISQ',
#  'v-uIHzVO96lOU1GHB1uhNg',
#  'oVIlNmDMeKNrYqA86894Hw',
#  'uHLwReGnnix3GUU1-nTvsA',
#  'E8NeVDFY_G1X68EwrSNiKQ',
#  '88wlCUSnJURsV0aGfUnlCg',
#  't3t0kobRZamD_u7gaD3hbw',
#  'Ver78QQD6DuAlVwA1Oa0xg',
#  'FwQOgcu52_vuM9Hihf1sjg',
#  'RuJbCweDBeXczwwPpKELYA',
#  'kRlXDnE8kdxnGYJCovvztQ',
#  'Pp-4I7A7ptl6KkEmzeItaQ',
#  'yDZfTTwMk4r4XfiBi9l2AA',
#  'uQar01oQx7S1pLXu7x-vWw',
#  'b11rTTE_DmZbot3CI_zK3g',
#  'd5Pjo3ZOdjUMyWsgcT1Siw',
#  'ttpjoQ7srsMyOYlas1u2YQ',
#  'i4tO3a4GIlqb1gxyf9wr2w',
#  'EUtwbHuqbXh-_rDeZVYGzg',
#  'Uxn2nyKhj1E38bY8l-8WuQ',
#  'nisPCs8wq33hozYPF8PcJQ',
#  'pGrYppdzgMXMkzgJYtBFrg',
#  '0i9Wc_-dL0DPMtuSLhLYYQ',
#  'XE0o07rowpg18NuQA_WAPA',
#  'EjnrGfxCmoygi5ar3r7kdg',
#  'VQW1M7SfQsgpnOeA0ZpCOg',
#  'tzxh4sKjB1pLLqnrWjagCg',
#  'oxwsBLbXNaK1JCLxXnQK0A',
#  'modV08hV3Tua5JchBLHgKA',
#  'wSIXVd-xMNXzydwLgg_5lQ',
#  'STlAT9CptR4gu28oj9982g',
#  'zH6bJCLJYWHeWrd2C3_lfw',
#  'WAXl_G6nzi8jYiwN9FLzgQ',
#  '68_NymJHpP2IvRw2H3_4UA',
#  'keqU-CRfiCjG0cvpRCvaRA',
#  '-vmnf6kWKKTZReNJ63AVZQ',
#  'DOZjUx7eQCJJku1exdV-JA',
#  'grNFCirBmT-EfJgn8CT-fA',
#  'BgUzuYCrXCg3TIFEwo9jXw',
#  'SSUEI9Pi3xorwDi2Kz2oLA',
#  '0LAsGGTy1bWjduT7rAbc9g',
#  'XkvY3RCFOmoBHFCH2-eK6Q',
#  'LIXTRxCqCeorTobA60dG5w',
#  '4Zn8yT8amJZEZmxoRe6dCA',
#  'uo5L6733MYeQwrwAzrBvEA',
#  '5-iUk7wBHdblMfg8HVg7Zw',
#  'wwv7hHhQoxLLLrTP6BXEAw',
#  'rsHsA6zCoNDuWpjj8VaeYw',
#  'NqeYqEHYjfkkpGY1ww6gMw',
#  'pdSkP_beNU18G_I0tI4XPA',
#  'EWm-p7OUiHOi5t4e8Lb7MQ',
#  'mkLKPb0ZG62gNlRPRXWJVg',
#  'n795voJsEFEgfsh9F6VQ0A',
#  'Doe__vK18UCBI9sXMRQrLA',
#  'iLKkhkKUaYP09Wwellt6Gg',
#  'DXsAzcD9fgwLJDHn2tX7ug',
#  'h2vmHdXzDFzBgVXoRC2LlA',
#  'ko3eokVcTyu8jjeG1gMfHA',
#  '0vSZUQvqpn6EM34P4j_o4A',
#  'gWUEPmNRwCl5XPdUsv9OTQ',
#  'qjbIbUeQHXdr7UEuMhEqMQ',
#  'sAJg5xpM8XcKRlHG1gUYfQ',
#  'xxZVReaWLx_tYhAE_21z5w',
#  'GE-sZAUpUcFioARwzdh7aA',
#  'dWCbBRf-V-splDE-HOl1Ew',
#  '19MS2RmBwmCQBslxpjlTyg',
#  'd-fLREorT830s70gy_NKOA',
#  'LgYAFFGBoAigt35iuC7S8Q',
#  'gDPwaoBjTvZSR7OHpx4Y8Q',
#  'wUVfgJUqKxKIPuF07Iv8Ow',
#  'pldNU9lpddRp7Z_tMnWMdA',
#  'XxjXM3agJo-jpcw8AiiixQ',
#  '4LnZBUnr7JY1XP2JbBJOhw',
#  'v7eNWxNZ5xvShjJT0OcaEA',
#  'KqZ7qKOvfhsMXznOMqa1tA',
#  'z0SnZEOKjalcjwJfh7_l3A',
#  'X_fS0gc_uUKm59Dcisd0YA',
#  'q-y4gWWunrnRhNIaQOaaaw',
#  'OISuko-zg1SuVqrwl1HYWg',
#  'ntzqAaz6gwaAcfyfsm6LHQ',
#  'jN9MvoXpHWKIJBbBYTZo8Q',
#  'sbzFH-U61PgsmxgLkqd_uA',
#  '4jp8B9I5wsxPnheOmN8JlQ',
#  'Qp5FGWbj6ZimtxQYm39wiA',
#  'crhmpSUTXElssdh6aoQIqA',
#  'NwFde9IFhDACiOVjooy0Cg',
#  'K2O-5-UKPOCeMFpBS_OlFw',
#  'eRdh5HdATIfLMhIwX5bvdg',
#  'T9Syd0k_bxGaEG-tkNlkKw',
#  'MASTWy4LRSk2CQvAdPgAmA',
#  'TtdoJOnRw9Jtsa84J59Lmw',
#  '1VHDbv9dKSV0JdZWKYqlng',
#  'HGMyQlAi2KtJZFlKz5bi5Q',
#  'bJ-haYYRBoN_hh-gstgMCQ',
#  'ovxI8MPMKR3Om_u-on_-Jw',
#  'YnjW_w6VZMxtJcUSjRVpcw',
#  'KHxKjsOjH8gkezvX41JdMw',
#  'mvlt_DuRgAOKJcj9ZbpnXg',
#  '2O_EE5KUGaF8sBRItp72dA',
#  'oUqPOG4A6NkogGuJwmFApw',
#  'eDcIzRmqRIE6fdmD08RCZw',
#  'TIT2-gNML7jvuyGlLFTvXA',
#  'G7ILg8RAATzamxi85RPaWA',
#  'XszQEZeDZ7uVcDfI1bDzmw',
#  'ci0cXntfSjH0R01Q9m2yYQ',
#  '5-Hhb_cxVHECyfl39uHowA',
#  'yi2ebNZDIK9ZqdISSUt7ew',
#  'naU9vYBtxr3l59l9dGePDQ',
#  'H9fB-Mca3YuxRIrr1gEDWg',
#  'WMWSrNdQZ8IclkrPKrNhCw',
#  'BBy79GyW3XzX6wwbFZn_nw',
#  'Sq07bcS5cUlMgohjE9fg_w',
#  'TMa1_G6nE0dhDDCR9K7QfQ',
#  '13B0EyNTymzGYGrxcFDcUQ',
#  'kDZKxERrj5larSCVWK9tSg',
#  'FrDlogIVdMp34X3tioMK0g',
#  'JQF8PFJRbnuBceHiQWHCnw',
#  '8zMDhmJnEtfymMP4rdSnSg',
#  'vIrFKXyfZJE-sgUXoqYwfg',
#  'ic89VqRpqU_M8_HFYYXigQ',
#  '_dGlP1Thn2J_cv8O9VvXAg',
#  'EHhXKgpfsj2_NUK7Et7GfQ',
#  'fJGdw1GJW_gg8IHCSDxDtQ',
#  'vj9FNvBcTPFx0i1P-T8fBQ',
#  'qGZsxXgsbpUkqjXlM1JgKQ',
#  'jzBap5CbDL7qCyBKySGUDQ',
#  'MsNCWGQbYO7o83EkThtFAg',
#  'lxZN7kqP8pVj3mpjqrzIOA',
#  '7-tSQ5lsXa2E6-89TfPQKg',
#  'RZVw9GE8_qf1aPdni53usA',
#  'Yqvd7c6BikoYr8S5h-ewPA',
#  'P5003jQxgJRef4bTlB0U5A',
#  'IOIOHyKRkQWdBOnsraDdWw',
#  'Zpn5lUKPgDlkntZqwWbfGQ',
#  'T-o5OXT5znBzFw_dG9VE2g',
#  'v8h05f5qug9-HVK413faYw',
#  'Ti_IW9pEaZyc38PFKLlBsw',
#  'Dk4YWSBM9M1MhTK0X3qdfg',
#  'aHkJcE5smN3zd2rx1x371Q',
#  'hXfFCfX-O8YEdX3fn4jSNg',
#  'WlpPj7fHlqeYfDRxS7DuQw',
#  'k3-x8KcSymMNREMgTGneAA',
#  'SoAOdhDNp4IfdKRj4zd-hw',
#  'Q26hhy-jM3BUT0EMuy835w',
#  '1NO_vP3Ef8Bpydon_HQekg',
#  'hDA6bS56-ilKvfD21x1xFg',
#  'n5VzhUjQt36ZcZUZ0KBkIA',
#  'B6QcUkcaZD-BTI_KRuxAVA',
#  'DVf9C-gWDsLLF2jxvvjogw',
#  'q967-v1nLS8SOniFU9LweA',
#  'y0lIo31ZbgUbOOwhk6AlBQ',
#  'b-SRBoTl09mWWxElYjjzdg',
#  'WlxiaBL98FH_Em8Pw1RVxw',
#  'BeXqqoULi88HiljNjrmqzQ',
#  '5j1JfE-ARcprpqmOP39F4Q',
#  'L8YNaDCbDXiRsTH4EYZd7w',
#  '1QPAUBjghXOwJ6u5noqHIw',
#  'UXePZcNgUX5loR52bU7Waw',
#  'IpSunaKftuRoBQ9gl7Knpw',
#  '2jfYJNYAT3ekf59j84nLsA',
#  '3lVpQycpNDCTBn1ORa3AdQ',
#  'RXAbTNEGNBn3_w65zcSc2w',
#  'GBs3qi3tur47NYG09MNYCQ',
#  't9ldF9ipG-GUDb2hTXROAg',
#  'T3UvAuvbG91OYBm202K2SQ',
#  'XYcMKDA6zJhMuw0jAJG45Q',
#  'bxfLW6_u2Gv3m5i6C5astA',
#  'SszK3jTfMXU7mazWco1rxw',
#  'KlCTe_9yehN_CptRrcDY3A',
#  '1Mc2GIXIRZvY79yWKyJ5KQ',
#  'yLgrsBBmySpk1-YiIaO3lw',
#  'GVZIGE0MSyhV5uD-aoceIQ',
#  'aV1TGaZ_BoQMToPUfEP8Kg',
#  'qkMoRuimxWEiUtdiaydrnQ',
#  'D-AEnFhLA1k1lxnNzSWK-w',
#  'R5_Ie-enMN_ZedVMLrgN6A',
#  'XV9AFuqAHusxvunGmgwKkA',
#  'Ui33V4ddBr7y5ay4YZzs4Q',
#  'eOLJ2yGtcUCxSz1TWDoVpw',
#  'bdTjMFlrttnAU4Vj6vWX_Q',
#  'tnz9d076qbVadvOukEUvzQ',
#  'NCO1HVa75sAdI8hVcU9BLg',
#  'hsT0-bigbvLyc4EPyWeFSA',
#  'cY8PJStJCHAPWakNN7iCQQ',
#  'KG0mKANkz5J4eHFJ44B0sw',
#  'AYcZ4wXJWoLZsqk7VNUgzw',
#  'xbIUsa0UyfXsZDfHYvPmgg',
#  'OkynJli_-xbzbn2y4lxrCQ',
#  'IAdHvH3ysw-u6InD58B6WQ',
#  'muDO9xKDUC0hQWyeYSAJGQ',
#  '5K97oWjUDABQChn4sl325g',
#  'ph_YTntMsMWSxoG5p8N29A',
#  'JCwRUsXYnbg6IJy4UjkqOg',
#  'Bz1DS2J28EzTLJHsaTyM7g',
#  '9Tih0yKXvmXpzLaDB5FZqw',
#  'tYybOBRF3KaTuOfjZ-GSAg',
#  'QAv7SKwZjGEv_QNDSJm8bg',
#  'vN6iipOXy2EW-d2h8Ut9EQ',
#  'Kp6YCs7yf-g26rk97y5_Wg',
#  'l4RKXIDolFGg7G5BnHn8Yg',
#  'H0tBzuw-BNtz-VGi1U_CuQ',
#  'hhIw5uX3pa7rm7XXr0cRzA',
#  'gfn_ODfVJ9J1mQBiNdH7Xw',
#  'YRaPa2dVRIDg-zv4MZuVLA',
#  '9eu-jV8BcGyVTEoz1OrR5Q',
#  '7w9uG5EIvbymq5vuyDyUVg',
#  'zDQg332AIPMqdrRkxjuurw',
#  'ZgaoxdFoIl2u6ACAByb14g',
#  'tkX8-Yw1ydq-TD5mOv8YOA',
#  '6a36BhyUkz6QuXgRd8x9AQ',
#  '9jXsHQyuuoYWYmK9ow2MUQ',
#  'RjiWOvVUxd7dFmdLm0QttA',
#  '9y04FfUcpnSlZ6sKRy7sbQ',
#  'kg1-q9WG2ztnfOh8_2r81A',
#  'sgjGQzjDdISwCrUJCsBAiQ',
#  'O8WaRyD4qSjKp7GQ00GvDQ',
#  'f0iENYEOsZrD_oIW6v3unQ',
#  'FKM_09P0PGB9MWtu0NxoZA',
#  'HZ_jxT8fBapRCN27GeWTAQ',
#  'Yg45ql1YopiGQpoh5C2PEg',
#  'R0tlwF899qVmoViAk7mFSg',
#  '0CAg9zw74l-sVrKtS01w1g',
#  'k_X9WV9jRJ_Qtjy--kTbag',
#  'p6u4prt_iysHULL1pEET5g',
#  'Cr3RCRcNWumGb-gWXh4lQA',
#  'r5yeblDr4AE0Y0KXgW5G5Q',
#  'xf8XzLjiIV2dDtKhTXsg3w',
#  'Er1DWlbriZEnEcAKGlzKPQ',
#  '5BWekMjv_eoZiv_7pk0yew',
#  'vMJcvJ69ldqcXdI48tuADg',
#  'zWMbVTv5XhMyWSW-fju8Yw',
#  'r-4wR8JJ6kZMeCX2IFB6aQ',
#  'BZFm-iWY4pNa74uaNN9xsA',
#  'I8Pnm5QB4MxyDs4fas8lXA',
#  '_VmJgU7lhlbyOJTJRJsiDA',
#  'JRnuYbGBlLjKOUgZEbpgCw',
#  'QRcwqZZAefmgwWaZOvuY3A',
#  'iLjMvD7w9dFoTKNYoLSpWQ',
#  'ZzsfvMIeoJIOs8KAQaGL9g',
#  'v1To0LdfdJ6tUbeiuk8qXg',
#  'Kg43WpbP1TCPgTArl3XdlA',
#  '4FTW5W_RLdy9r_qUJb0N8g',
#  'sLAZP0YZFzQRbSKkHrpkug',
#  '67Lnk-hH-eVu9PfPguNU9g',
#  'fqb-ijqIyFdNPicTKJ4HxQ',
#  'jvsYNb847BeqrQ712Unrrg',
#  '4sDJfpR12pKX3R4FmbEEag',
#  'XW3Svdh3DECe0CykO23ECw',
#  'U0F6mK1VKu2nrtzPx_PuQw',
#  'ZqsaGh5JqI3Ketnt2_jmTg',
#  'zXqKGvH1OItQc4rvnSGP6w',
#  '7ZKbyzwAwRHRGRRf88-Uew',
#  'v1pwvQTXWnTTZec5Ru1uEg',
#  'D0NvU59pVTBX4P5yvxTu3Q',
#  'SRt8rsWS6P9IB-VzpzhrqA',
#  'HTGXXTBRswbiSfjCRzyC_A',
#  '2exqsy12akam7DxmEywtZA',
#  'pTe8uGM-AQPm7Z3cS7TMtg',
#  'JM7cN7-T8oqbza9RVO-dcg',
#  'ICPkkU46YA3D5V6n65D2_Q',
#  'CdBbRfc8w3p3Vuazgflj-w',
#  'rBOol48t9EkIWnxBc38nng',
#  '0a3TvG6biWCYIkwXahF94A',
#  'rbxopYcKmZNSmsnDuAQJMg',
#  'ma3OUBMGDp1xQbG2i_O9Wg',
#  'SJeWjEODgyX9JMZ1Hdzd-g',
#  '7Q2rXM8dEo3K-A1crBXLeg',
#  'VvolZFBslnKZsAyTaaKCDQ',
#  '_QCoTilHS_yNFs6le3ReAA',
#  '93kk_5QssrNRIB6apx5XAg',
#  '-kSbToBGdOZ4jKjHjAJwxA',
#  'vViaV2OSZVKoq5CS3SW-ZA',
#  'Mysk1toyaQ0JYzesqT-Q4Q',
#  'U6bnfmrs467Gq3Q5ARrIzA',
#  'fA6TOfQ7KDdeghtKBW2EOw',
#  'ncvDhcGOvNarAlWKzbcWmg',
#  'IqcZrtMtWvO5krU7yJud4Q',
#  'R78UrKKXcRhzqdJ8aDelPw',
#  'HgtpUS17vWyr6XjgrVwzng',
#  'S60xhALysMN_DmFqggQf5Q',
#  'Don5OtVppE6pfG8HPWL_5g',
#  '4Q764q90ErzTDjhTIDdu2g',
#  'Pcn64j057vNqzBgQQrQPDQ',
#  'a77Vt1zR6xVaDq2QIsHoZQ',
#  'fY7Mz0yCw__7piY2JQeM3w',
#  'A9PFmQLFqm24NB4tP3UxkA',
#  'AyG_iLHsGHUMbpegGPy8tw',
#  'r66-esgHfEv11KNbSw-VCA',
#  '1ENnh2lsIK5Gehh3n7IBpA',
#  '92PkUA5C8tBSHWtgqXIh1g',
#  'b0RITTS0WTz_aXEvT6DA7g',
#  'NfK8lTbCB8hY1DYjwfhdtg',
#  'aSrLJ4Bv5YAIuNHwzEYDUQ',
#  'UemHFfTG9Gfh58_YytwYvw',
#  'rx2222dGzcSRsf7KC_Quiw',
#  'ZFvxtRFmb_-2OzmGkS1ZmA',
#  'xgAtGG_iOyWUf8Vc6rx19w',
#  'diZL4qZJqLM034BJDhI0mg',
#  'B-3l1DVms_BBSy1DggTujw',
#  'DVqy0qNKw9XoYOIVn59gVg',
#  'IUweEKjdTpXNWdGTOsjR3Q',
#  'qormZ4GKvmi4Fqom6VA5AA',
#  'UXT76V4CX6ftV5_4FkaYZQ',
#  'lrM5mLQ5uZFyCdsDC---Ag',
#  'sGBjYjdwN2aSc1KQvKP-2Q',
#  'CNPY1vKOf7sq-50O6w9fWg',
#  'jAEUjM6_ggL8cPMrbd6pvQ',
#  'E7nIltc1Dh1wEzvsoi1LrA',
#  'yU7ESPUzev9n0vG0tAEmpA',
#  'uLMpdpieIIDPo-5cB4xxyA',
#  'dZE-UK0PSZkVtBnnWwoRfg',
#  '0rKIh4BZjgk0WQfXo1vY8Q',
#  'wxWcfe1eN9GUf8EvNu4UfA',
#  'Az0YUrQiP4jyYzFg7GECuA',
#  'bZCSRJEM43y20HQCLMlyrw',
#  'ymLUxunMeEj3NoR7xXmtag',
#  'Ulom5cTTAvle-O4GvcLc3g',
#  '6cHP4_jl5ERHLFOI0AGbIg',
#  'FQSVQWSmtFwp1HZxTKEqsQ',
#  'Kxdhv349ibW95kJsOs0acQ',
#  'z22dPEFMXgBza8CmuQvzxg',
#  '-qZB2nr-UETYQa2CQ1j_yw',
#  'gfPwDUBE-Ee6tCSLkaN3Sg',
#  'U7hwhDfuixAhlt-73mgZaQ',
#  'RaMHCHJb2-Lbmx-1BILamw',
#  'Gmo4grj1sYzKrJB5HwBzxw',
#  '_7yklWu-hR8JOZqTTj3uBw',
#  'F77MwntRSnwk2JhJLAOnKg',
#  'Fmzm3lzySlNkyi-qY5pmfQ',
#  'fMUqsaiWmsVaEWP-S-51gg',
#  '0PF3_gnx3oI48Q4xi3D0uA',
#  'Qma_t7qhGHV6hTKdvmxeag',
#  'Evb3mrrqgzZG43CU8IhEbQ',
#  'qnCG9dTBqN1PnzRdtuaMYQ',
#  'YFDY98SAw0ntiLmeWRmwFw',
#  'oenF01dbCawAUP3k8HEQMQ',
#  'uLm_upURLrMSqT-fSsc8uw',
#  'dTHZtHL8QgNs-4SeJicrSA',
#  'sK6zvygUYox9d5NPhUf63Q',
#  'Ce2CSC-DCcBNidaY3K8sxg',
#  'eSpZ7lMhEs1E07Ot84Q1Ug',
#  '5danjMfCGz1EgIC3oHsAwg',
#  'gtIAQMSAfJTitgeRezv8dg',
#  'GhyTmPOFN67dFHl_cwgFIA',
#  '7-jSbcQX-D68sg2mK05Tqg',
#  'xHbs-z82OIEJsqQvO9ETCg',
#  'Kub7NAeaREswQlVodZrxsQ',
#  'ZnPxJe-CERUk1VxQd8ayOg',
#  '_OKqkvJgN8z2uunCsBhOgg',
#  'XaaQgK8KD_xS_5p-fBQ0fA',
#  'JLiPlRKIZ0CktABrVQWOaQ',
#  'pQNg9P5nO91shiJ5ezr3Lg',
#  'jO-Smqu0eRMLk8r64ccM8g',
#  'R_mjywpztcud3SWSfeAqyg',
#  'DC1laGKACQ5nKYjb5R5BLA',
#  'LY2T9QnoQo67Uw4-7MsjZw',
#  's3IedOeIqbF8SZpcHQ-zeQ',
#  'phv9vozhP82_pzq2iKOj7g',
#  '95hEhqr77ECcksr20lXe2g',
#  'svut8ftY2CDolQMc_7EUvQ',
#  'o-E1JyikWkf9NtoI5x4TXg',
#  '5Gjpl17sRIGIWOmdoa6vIQ',
#  'gf0Ho3aXDTlolAluBlo39g',
#  '5yQz_20ntdZnAWl0RwekBg',
#  'q8kwWoT3ataEs18VgAZWtg',
#  '78vjtdv7zHqYOCmOkabNEw',
#  '90DgZHQd7JcI7hEIO5bg2g',
#  'KLu200LkmC202iHs3tVyaw',
#  'ic7AQKnHe4iAaBD9R8U9aQ',
#  '9HIkML8FvgouHUH8SN93Kg',
#  'Tz2qd_SqHGwC3X088R2fuw',
#  'pTB69nhhihzkWZbVXjuF3A',
#  'Z81y5tCOueAfroAUb-WY3w',
#  'gc5w0ADAV_lvbUF7ZvMqtQ',
#  'PhjfEyuW7MTAXTSXmp6X8g',
#  'UqxDPhO9ojnwYEeTjmX8rw',
#  'pm0n_TLRLuoyp3S1F-SEFA',
#  'OYfDjZ5azpWeLcJmFjgl9Q',
#  'w_k5o-94CAkPMdi19n8SEw',
#  'rXewImB2On8hiJ-7O-UqlA',
#  'BuOgmL7VVrvQgcSVjNtAUA',
#  'TVuRjMOAc63leptEFHoDOA',
#  'Fgw2kkBgS9q19hIh6fIKWg',
#  '7LYZIhHNJha-aDaulmBcZQ',
#  'lB4anBKWypGyGfwvrtOueQ',
#  '8BlxeyJcCOqqm9ACZ8-LAg',
#  'MYSgFWRg_0ukUVw5RRzXMA',
#  '_ne_Rv1JaDoD2D5LMBwkjw',
#  'T8R3FnnuvM2RDOulHAS_Mw',
#  'AULM-5ABQiAdRJnPeIo79g',
#  'rzfuulABd6wtcnmxIBm6aA',
#  'toZwatCbm_q4IXxoNduOFw',
#  'Z57-X3KyDlebQwWXHwsQkA',
#  'wCVg1HUZpMRydTRYtzZSoQ',
#  'S5cxD5K34RH7Gx0COq50xQ',
#  'ZRa9bpX5XBPdZUua35X-Ow',
#  'Z140rX-6V6uwvH60Ua6nsA',
#  'agtjYhttr7WzHQia2nkxPw',
#  'L1oKr9LAb-PyF3RhU2Nh5Q',
#  '7oaE9QA_et7ZrXEnSUu-GA',
#  'HHy9yIjW07VHUE6nXVbsVA',
#  'HZ4ujlcJ38m5HiaRWRCLqQ',
#  'oHQjfrbO2MwqjCqVtzosyg',
#  '742WJ4DxQSN_WAfF8Xkp-g',
#  'kKdjYFmb9WHX-DGg9wUSFQ',
#  '_juOIKgjEGplDpkIsRWxjg',
#  'vVa9feamQbMDyi_p9pXwcw',
#  '6OuhVEQJ0Ym1W__6yuDNjg',
#  'uLZaugr1siDqEkGUEARREg',
#  'w0_iB9GXTd5FgtV8Pt8dDA',
#  'awl7sTI1cRNXp71tDZmsrQ',
#  'hY4IY4IwjLCjGAcXLJO2Yg',
#  'oZH0bErg-VYi6YrN5Sm8lQ',
#  'enhGXuwhgUQeqIELZ9kvKQ',
#  'wzkFf6iMP33tNnt0m1DsiQ',
#  'RS78I0iEfHU79HQ1D2e_Hg',
#  'dTqBriNavgrjKYAHZ2E2iw',
#  'Olweowp8diVhubuLurSjdg',
#  'Ws5w7q-53RlOBO2p6LoylQ',
#  'sJg2zGR6HmJ5iZUE6wZEyA',
#  'mJojnNghhxA9d1sYjnFsaQ',
#  'hRYilRsifrqkz8N8yDztaw',
#  'BYpegOvfmBm3qrsyZI4ibw',
#  'zeQFCUO7AQzNJptDo9E93A',
#  'zBJ-W2uNdo1s-kHl0SFnhg',
#  'lgT400ziPpxSlaSo9uyFZA',
#  'nUoqXxyuZgI9MI4yyAadVw',
#  '03E3SB_mh_qoUzike0dkEg',
#  'A1HU8NP0nuq9I25qEdBV9Q',
#  'fPmW6mMwSE6ZvZArRy6brQ',
#  'mhmh87By_Nb5C5MqGMZieA',
#  'IXe344cwOgj3eoo9yVqJ_Q',
#  '_7RrwSvMM3zV0VK5TsL_DA',
#  'MJOAzn_QPJTvrXnfiH3WMA',
#  'k2-EWXBd-ZfRPBy0xtznhg',
#  'IEu0hjWI61dIqAjdXZUCEA',
#  '9ww_RKaVXw9xWPLbxgUzew',
#  'Wfl5Ncqo6duZymYjkNLQ8A',
#  'Y1OpRhqB61aqGZ4fHir0Rg',
#  'daXVMNOXQzuVkZYBJQiFxQ',
#  'Pjj3U0dlEkby6SAPS9UQlg',
#  'rUFg0vB2LFWPHGRECQf2yw',
#  'B8u1K47afETt1F32fyU6Ow',
#  'B9raAOSZRetc3VVVhOOgTw',
#  'mIa4DqqmQD_vj8XdImXcgQ',
#  'W_Wd-BoKvbqHsSzwm1e9Bw',
#  'BZhMd-3jIR7T7UYGCvb_Ug',
#  '_PJv3KX0i9tCMrKhwMzC4g',
#  '5O34c8mfe7Ss9rs0pN8hdQ',
#  'c79weqo-TZexcAvifk0m_Q',
#  '_KQalgwKv9PoUmCM7o1IqA',
#  'F-ko1fsXK8NR19t9dxqUSw',
#  '6M29eCBoe8qMZPrhwQ2IwQ',
#  'AnQe8sFB-Vj19J4nzLfUag',
#  '_O20AUGJuC-anAOpST96mw',
#  'CWLoBclvpAt72kCzgFdytQ',
#  '_3-ElQ94W5mAwBMZ2Hl8hw',
#  'AgjSAiG4RUBVMtqz1kBFvg',
#  '1YK6-VoLYSBCxcCXjQQrng',
#  'qYNBEUv5ejwXu8VS94dwfg',
#  '9MiSEZY55E-8eg0ZJvT_Zw',
#  '5dsvIudoiftZn6xJ5k0fhg',
#  'Tp-Hg5dl-fqFKWEOa1BbnQ',
#  'ZecW8d7shVOb9R5T0E5gNw',
#  'kvMonPFgekh__nY1gylJhg',
#  '6WWDyIZH7HY9oBjPU7A32A',
#  'kOhzIFv7NTXJAFUotgK7ZA',
#  'ywR7r8vCjzMh3FDLSoHKaQ',
#  'yn4xDic3GKkG0R3mtENnpw',
#  'qozN87Y2BTOMkKCGZSok3Q',
#  'qkmUsr-o5naRJEnUIDogTw',
#  'RrxVIfp8QSCUM2NmxBegpw',
#  'YOpyowEL_AZ0eRHr6S0oNA',
#  'XTsWjE3tTb3OlvrMvE0QKg',
#  'WxHJkBRBd4usu4U7rRaDCg',
#  's-eIULJrq8ij8f6_kMeiPQ',
#  'RJAo1sSzDyDWA1C8_eKBsA',
#  'HDJtN3A3CRjf7WCIF68qCw',
#  'GFxeKFIIt8NjZQCWkFtP7A',
#  'E8Z1mYXwJreL335KdWdv6Q',
#  'peURanMnQ0DJYv9uG2eG6Q',
#  '1lqTafe9y8Ios32EG2AvhA',
#  '-_65e6NWuLWgSnfQgmSDAQ',
#  'Z1ltgn1cLBknKzvyffBDYQ',
#  '3_yp8jWD5yL7DvPrW1ay0g',
#  '0FhJ5M7P3MZJ5zn-SGU1tw',
#  'oslRSomZ6LpuouuKvn-9xQ',
#  '2dwmiAeQ3oCbVZ3TmlXICg',
#  'riZeWbEkRF0jmpCNhjhj4A',
#  'v5A8vtFtUlGzUVdWSn9iiQ',
#  'qyrOg9LjL6YI6jZKwFIQVA',
#  '27MgSmoyeLn-51HVm3R2Vg',
#  't4q3HEGbjnHKHqtRhMuPmA',
#  'qmWigBkEOfZiuH7Z58srWg',
#  'WLyg1w4mheQc2fp_oHpNkg',
#  'GvcQ-6hf1j6yW2DFLLievQ',
#  'dfMUopjQTezi16cJxLgSaA',
#  'sbwnChBNYYrPsEYK7dYIyg',
#  'sTdAuZdxU7XM-VEVe3ZL4Q',
#  'XQqURh-BBT-ZIjiny58ElA',
#  'F8AZdmlxdVKnkkkXfkwKeg',
#  'V_i8g_F1cirpqOfUBCyETQ',
#  'JtVVKdR-xq5CShI2-fAYeA',
#  'fqE2bASU1bGFRQ4Wu14xUQ',
#  'qvbGlXUG9b4thvO4OE-Mww',
#  'SRbYxeKNlFJYzu1MBKCwpw',
#  'OzQFe0p01xf-JXeBidp8fg',
#  'e8cUhUEdk-NXavHAlXE--Q',
#  'x3nMLJuB55KjOn4uiyKm7g',
#  '5uVRxWEusYfcQoG8spxJuA',
#  'GmE0u3MugMbTVgSB-vRORg',
#  'eHPTGGlfQ150Uo-Oi5jU2A',
#  'xbkEHerbTkNAXydRhQYKiw',
#  '7zmk19uhgWCyse1s_6_YBg',
#  'j74BT8VLqdOLRqEKrjkQOw',
#  '5K22geADVwzTlZ5Lg-5prg',
#  'Kr820C7h9Iwh1I99g1mkCw',
#  'K3_jljvHJwgGgKRfV076YQ',
#  'z1WaFIJtlZw0jiMU_4275g',
#  'Y10HmFOxpUKMgW0gWSiLAQ',
#  'AYyX4CQoDYVwfsvMnpStAA',
#  '6WloSkDmGC_HjZjrlTg8-A',
#  'w7hHM8TyVyAEuPyJJGM4kA',
#  'd6X2yxUbuxHgimTveNCVuA',
#  'b4qJFNH3iDhALBGGCNi8Jg',
#  'Z1SjLfAdNA2tipTkrKodyQ',
#  'xCic5xF6uXlrLKZ6sxdxMw',
#  'P_EEq0PtrdD3FFUii3BTVA',
#  'wshNnBR5cbvSejgBKJC6-g',
#  'M0X496Ze4TMrNooQgdn_Lg',
#  'M42Ntd71Knrh-PSf0bN9JQ',
#  'q7YGWlw8gp14Vyi5yc8BPA',
#  'R3wzYTCLIaiFOi9wtDTdGQ',
#  'p7L9ciyGHX6d2zAvKuXBZA',
#  'Q2D_q_irV7W9vhsZYWGsnQ',
#  'g3ujOMJLSQJVt_ilO8AaEQ',
#  '4o-yxebK7jWyr39sFGmeuA',
#  'ITw2HbhhKG8MiQp4jBsoGg',
#  'KScpef1XXUSpdkP0-NP4UQ',
#  '_a5MAe49XVpbicTZIqWlSA',
#  '11PP3nbtaJ_3UEg98PExWw',
#  'OSpAPY8LAZAJsYG5bd0iiQ',
#  'uMY3U7_eVEUkPfjNeKBDJw',
#  '8MJmwHHH0pl8QqRq5gIwrQ',
#  'Z0LeucIh-ZqqC2suFX3yIA',
#  'ZS4WWqrgq0AbSOAojoMblQ',
#  'VqSct-77_WqHIiTr3E6y9Q',
#  '0y35jYAB3tbuiDCbnc1Otg',
#  '9FNplC2M4ygKnCZ8twHHpA',
#  'IgUIetqlGA_ioxkUX2WTMw',
#  'ZN6BDXUiHK_XeRf7mI5UZQ',
#  '8faXHqe-3tL06qdSznsv1Q',
#  'rb9E_tpXVZxh3Z2KRvMo2g',
#  'y3k2Fohx0YOLPTyzQ7K55A',
#  '0MGTwa68VsxIQuohqnNJpw',
#  'vmQQCoYSckb7H20HbRZ7Ug',
#  'TGpeOiZOnvp06o847rznrw',
#  '15n_Pcq_cexJcqcIddBhkA',
#  '4SwxqRVhLJtqkszaxMayCw',
#  'IWUQJXt-TD1WkI_9LgQU6w',
#  'LHBSNSbqaMgBBaSlpNjqbQ',
#  'UZN9Z3GcvehzSv6y7sED6w',
#  '4EVyd8wqtiVu-b5APGph_A',
#  'pgl0AFeL2aSR60IFZvFsDg',
#  'XzRbjQDq3I-0c1-8Wpov9A',
#  'sacrzgwSGMz5SNV3PGcs5A',
#  '8G3_cEtwfpc79Hb0JLEa5Q',
#  'xy5d6e1nDGVee9BEPI6_vQ',
#  'VmBAAgECOLCpERxAQPG5-A',
#  'RxF8cqTruNyZvAZaGiA9ww',
#  'hVjAHf7FS4-lfi_Ch3ikUw',
#  'pPo6Cfi68yJsN79DM0Dong',
#  'cuMwO06cUxUzET23opQlPg',
#  'bhim9LWssfnn91ukuloF1g',
#  'a2y0ldSEmTo8pv_1ayB7uA',
#  'VNli-4LWZC9mQ1RCr2AkXA',
#  'cClzKbUuLsQkxmBf_Hyevg',
#  '2SXGtMT1pUZP6iPglEkB_g',
#  '5UhUCrdUgCrVSB1BWabMTQ',
#  'nxhAbrxB8VOVUsgbOVUbjA',
#  '5FwXKVhZNGXHQEXxdAvCaw',
#  'qiJ2fVPqDATBoszmfmx1QQ',
#  'iknrka4_B_ISGwrk-QWiiA',
#  'a0rZMDgN2P63w1WGdq__NQ',
#  '-0MlrpuonhR_zTqGqJqY-Q',
#  'n_MlAAbTknTcjD_Qymf2qg',
#  'Dm6aL0Q6iESepICYEJdEFA',
#  'O3643nJlz-CP9LMMHSuiXA',
#  'M1cVwxcjdkGzgjGHebFhSg',
#  'OdbM6w3pDkuZ3BBQbmdueA',
#  'wqjOfKjIjWbxYZQZZ3OOOw',
#  '5jDEHdWVl2RupWKykKSL0Q',
#  'qKG4TWFk2KNibHdXGDxTww',
#  '9PP7Zj0Ut80dP2etg2BlrA',
#  'MY0CMm92D63OZvf5z2TGog',
#  'qai9c2o32GPlnqTMH4JlSw',
#  'IcF_TdTbHtmrSzCOLSgeSA',
#  'UvU9DHCLdfkPoDfKc6_NLw',
#  'IImGCZvGSOdj2J4cL9mFDA',
#  '0IqTbH9q-pLmw5QTbHEs_A',
#  '613P4x40k60JCAff_MrewQ',
#  '5zXb7KWLuXWU8sRTk4SojQ',
#  'JLuKaoOIncSoxZ9o6Km1tw',
#  'R80kLOxPQIxB5uwlhSht5A',
#  'F9vhbCxYN8S6ODm5wLktRw',
#  'Q0rKzQNw9R95spOs3bOvFw',
#  '70rgfVoF-rX9HgQpESTLxA',
#  'zCfFigPIy2_D2lO5YF_FKA',
#  'qWv2KWw3AvXhEXJedLiSig',
#  'cTWZhgURaFqrhDROki2PHQ',
#  'Qo1lqklAhe2FKW3qvjAvMg',
#  'bzEBPu1h-_z7Rf0SzapA7g',
#  'zQ49Gj5Ha1evM8ZgeSJdtw',
#  'OFeuuv07SwuL7hxl_MxvSw',
#  '9xKZ8lX4gIUmkA8qjSQAnQ',
#  'Pz0E6hMyEgUD6ia-oYXwgg',
#  'NmPJ4a0UP8SivcGqj-Yt6A',
#  'rlcn-J5gjo8IJJkQtm5Csg',
#  'aJYeVjArk-5iuyiNLlIseg',
#  'mEULzBvkf6ohcFliLNxDXA',
#  'mRigFJ7lv2pZDEFalcaajw',
#  '24qByLihUJXA1_jkiNr6XA',
#  ...}

# %% [markdown]
# ### Restaurant Covered Ratio
# - Out of the 15K (unique business_id) stores(business) that yelp records,
#
#   about 7K (46%) are restaurants/food-related stores.

# %%
restaurant = 0
for ts in Bid2Info.values():
    try:
        ts = ts['category'].split(',')
    except:
        NoCat += 1
        continue
    for t in ts:
        t = t.strip()
        if t in YelpFoodTags:
            restaurant += 1
            break 
restaurant/len(Bid2Info)
# Out:
# 0.4609633778085217

# %%
restaurant
# Out:
# 69304

# %% [markdown]
# ### Review Covered Ratio
# - Out of the 699K data, roughly 325K are commenting on restuarants/stores relevant to food.
# - The coverage is 46.6%.

# %%
# review covered ratio: 
isCoveredReview/len(REVIEWS)
# Out:
# 0.4662050733303959

# %%
# !cp /share/home/yuxiang/yelp_data/mapping/tags.txt /share/home/nana2929/repo_en/data

# %%
isCoveredReview # inference 的時候把不是餐廳的丟掉
# Out:
# 3258904

# %%
len(REVIEWS)
# Out:
# 6990280
